# %% [markdown]
# <a href="https://colab.research.google.com/github/Agatha0709/python2/blob/main/aulas_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**aula** 1 ✈ ⚓ ❄

# %%
print("I competição de programação dá Start")
ano = "IX"
print(ano, "competição de programação da Start")
print(f"{ano} competição de programação da Start")

# %% [markdown]
# #**aula** 2 ⚗ ⚛ ♾

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")

# %% [markdown]
# #**Aula** 3 ♥ ☯ ☀

# %%
numero_de_alunos = int(input("Digite a quantidade de alunos: "))
numero_de_monitores = int(input("Digite a quantidade de monitores: "))
if numero_de_alunos + numero_de_monitores + numero_de_professores <= 50:
  numero_de_professores = 8
  resposta_positiva = "pode ir"
resposta_negativa = "não pode ir"
if numero_de_alunos + numero_de_monitores + numero_de_professores <= 50:
 print(resposta_positiva)
else:
 print(resposta_negativa)
# Out:
# Digite a quantidade de alunos: 9
# Digite a quantidade de monitores: 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2213424875.py in <cell line: 0>()
#       1 numero_de_alunos = int(input("Digite a quantidade de alunos: "))
#       2 numero_de_monitores = int(input("Digite a quantidade de monitores: "))
# ----> 3 if numero_de_alunos + numero_de_monitores + numero_de_professores <= 50:
#       4   numero_de_professores = 8
#       5   resposta_positiva = "pode ir"
#
# NameError: name 'numero_de_professores' is not defined

# %% [markdown]
# #**aula** 4 ⚾ ⏰ ❤

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3749446930.py in <cell line: 0>()
# ----> 1 P = int(input("Digite a posição da porta P (0 ou 1): "))
#       2 R = int(input("Digite a posição da porta R (0 ou 1): "))
#       3 if P == 0:
#       4     print("C")
#       5 elif R == 1:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# #**aula** 5 ⛪ ⛓ ♟ tabuada

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
        numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# #**aula** 6 ♈ ♒ ♋

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")

# %% [markdown]
# #**aula** 7 ☣ ⚰ ♟

# %%
print ("sou seu assistente virtual, como posso ajudar? \n ")
nome = input("Digite seu nome: ")
print("Olá, " + nome +", Qual é a sua dúvida hoje?")
# Out:
# sou seu assistente virtual, como posso ajudar?
#
# Digite seu nome: agatha
# Olá, agatha, Qual é a sua dúvida hoje?

# %%
print ("Sou assistente virtual, como posso ajudar \n")
nome = input ("digite seu nome: ")
print (f"olá, {nome}. qual é sua duvida hoje ")
resposta = input ("qual o assunto que deseja tratar: matematica, python, javascript ")
if resposta == "python":
  print(f"que bom, {nome}, vamos falar sobre python. Python é uma linguagem de programação de alto nível, versátil e fácil de aprender, usada para criar uma ampla gama de aplicações, como desenvolvimento web, ciência de dados, aprendizado de máquina (machine learning), automação e desenvolvimento de software.")
elif resposta == "javascript":
  print(f"que bom, {nome}, vamos falar sobre javascript. JavaScript é uma linguagem de programação leve, interpretada e versátil, usada para tornar páginas da web dinâmicas e interativas.")
else:
  print(f"que bom, {nome}, vamos falar sobre matematica. A matemática é a ciência que estuda números, padrões e estruturas, sendo essencial para diversas áreas do conhecimento e para a vida cotidiana.")
# Out:
# Sou assistente virtual, como posso ajudar
#
# digite seu nome: agatha
# olá, agatha. qual é sua duvida hoje
# qual o assunto que deseja tratar: matematica, python, javascript python
# que bom, agatha, vamos falar sobre python

# %% [markdown]
# # **aula 8** ◀ ❣ 💢

# %%
import random
dica_do_dia = [
"Comece a semana com foco e propósito 💪 pequenas ações hoje criam grandes resultados amanhã!",
"Mantenha a mente leve e o coração grato 🌱 o progresso acontece um passo de cada vez.",
"Metade da semana, metade do caminho 🚀 continue firme, o esforço vale a pena.",
"Renove suas energias ✨ respire fundo, sorria e siga confiante rumo aos seus objetivos.",
"Você chegou até aqui 🙌 celebre as conquistas e aprenda com os desafios da semana.",
"Tire um tempo para você 🌸 descansar também faz parte do sucesso.",
"Planeje, sonhe e recarregue as energias 🌠 para uma nova semana incrível!"

]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n ").lower()

  if pedido == "dica":
    dica = random.choice(dica_do_dia) # escolhe uma dica aleatóriasair
    print(f"Dica: {dica} \n")
  elif pedido == "sair":
    print("Até a próxima! \n")
    break
  else:
    print("Comando inválido. Tente novamente. \n")
    break
# Out:
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  dica
# Dica: Tire um tempo para você 🌸 descansar também faz parte do sucesso.
#
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  sair
# Até a próxima!
